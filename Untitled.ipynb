# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from PIL import Image
import json
from tqdm import tqdm
import yaml

class COCODataset(Dataset):
    def __init__(self, root, annotation_file, transforms=None):
        self.root = root
        self.transforms = transforms

        # Load COCO annotations
        with open(annotation_file, 'r') as f:
            self.coco = json.load(f)

        # Map image_id -> file_name
        self.id_to_file = {img['id']: img['file_name'] for img in self.coco['images']}
        # Map image_id -> list of annotations
        self.annotations = {}
        for ann in self.coco['annotations']:
            img_id = ann['image_id']
            if img_id not in self.annotations:
                self.annotations[img_id] = []
            self.annotations[img_id].append(ann)

        self.image_ids = list(self.id_to_file.keys())

        # Map category_id -> consecutive label starting from 1
        self.cat2label = {cat['id']: i+1 for i, cat in enumerate(self.coco['categories'])}

        print(f"Found {len(self.image_ids)} images and {len(self.coco['annotations'])} annotations")

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_id = self.image_ids[idx]
        img_path = os.path.join(self.root, self.id_to_file[img_id])
        img = Image.open(img_path).convert("RGB")
        w_img, h_img = img.size

        boxes = []
        labels = []

        for ann in self.annotations.get(img_id, []):
            x, y, w, h = ann['bbox']
            boxes.append([x, y, x+w, y+h])
            labels.append(self.cat2label[ann['category_id']])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        target = {"boxes": boxes, "labels": labels}

        if self.transforms:
            img = self.transforms(img)

        return img, target

def get_transform():
    return torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

def collate_fn(batch):
    return tuple(zip(*batch))

def train_model(dataset_root, annotation_file, num_classes, epochs=10, batch_size=2):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    dataset = COCODataset(dataset_root, annotation_file, get_transform())
    if len(dataset) == 0:
        raise ValueError("No images found in dataset!")

    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)

    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for images, targets in tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}"):
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            optimizer.zero_grad()
            losses.backward()
            optimizer.step()
            total_loss += losses.item()
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {total_loss/len(dataloader):.4f}")

    torch.save(model.state_dict(), "fasterrcnn_coco_trained.pth")
    print("✅ Model training complete! Saved as fasterrcnn_coco_trained.pth")


if __name__ == "__main__":
    with open("dataset/data.yaml") as f:
        data_config = yaml.safe_load(f)
    num_classes = len(data_config["names"]) + 1

    train_model(
        dataset_root="dataset/train", 
        annotation_file="dataset/train/_annotations.coco.json",
        num_classes=num_classes,
        epochs=20
    )

# %%
import requests
from tqdm import tqdm
import os

API_KEY = "66NbaZDdr7VDTLcnTQUM"
WORKSPACE = "idpr-l0qtl"
PROJECT = "internship-wlvef"
ZIP_PATH = r"C:\Users\91935\Downloads\archive(5).zip"

url = f"https://api.roboflow.com/dataset/{WORKSPACE}/{PROJECT}/upload?api_key={API_KEY}"

file_size = os.path.getsize(ZIP_PATH)
chunk_size = 1024 * 1024  # 1 MB

with open(ZIP_PATH, "rb") as f:
    with tqdm(total=file_size, unit="B", unit_scale=True, desc="Uploading") as pbar:
        def file_iterator():
            while True:
                chunk = f.read(chunk_size)
                if not chunk:
                    break
                pbar.update(len(chunk))
                yield chunk

        response = requests.post(url, files={"file": ("archive.zip", file_iterator())})

if response.status_code == 200:
    print("\n✅ Upload complete! Check your Roboflow dashboard.")
else:
    print(f"\n❌ Upload failed: {response.status_code}\n{response.text}")
# Out:
# Uploading:   0%|                                                                           | 0.00/14.1G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      22                 pbar.update(len(chunk))
#      23                 yield chunk
# ---> 25         response = requests.post(url, files={"file": ("archive.zip", file_iterator())})
#      27 if response.status_code == 200:
#      28     print("\n✅ Upload complete! Check your Roboflow dashboard.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
# ...

# %%
kaggle datasets files mughe/sh17-dataset-for-ppe-detection
# Out:
#   Cell In[2], line 1
#     kaggle datasets files mughe/sh17-dataset-for-ppe-detection
#            ^
# SyntaxError: invalid syntax
